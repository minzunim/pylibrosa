# %%
import librosa
import matplotlib.pyplot as plt
from dtw import dtw
from numpy.linalg import norm
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %%
path1 = 'mp3/midnight-quirk.mp3'
path2 = 'mp3/sunset-beach.mp3'

# %%
# mp3 파일 불러오기
y1, sr1 = librosa.load(path1, sr=25050, offset=0.0)
y2, sr2 = librosa.load(path2, sr=25050, offset=0.0)

# %%
print('y1 =', y1)
# Out:
# y1 = [ 0.0000000e+00 -2.1827873e-11 -5.0931703e-11 ... -5.1408060e-06
#   5.2380165e-06  2.6243015e-06]

# %%
print("len(y) =", len(y))
print("type(y) =", type(y))
print("sr =", sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("len(y) =", len(y))
#       2 print("type(y) =", type(y))
#       3 print("sr =", sr)
#
# NameError: name 'y' is not defined

# %% [markdown]
# 1:20 80*22050 = 1764000 => 1774656

# %%
plt.subplot(1, 2, 1)
mfcc1 = librosa.feature.mfcc(y=y1, sr=sr1)   #Computing MFCC values
librosa.display.specshow(mfcc1)

plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y=y2, sr=sr2)
librosa.display.specshow(mfcc2)

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
print('Normalized distance between the two sounds:', dist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 9
#       6 mfcc2 = librosa.feature.mfcc(y=y2, sr=sr2)
#       7 librosa.display.specshow(mfcc2)
# ----> 9 dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
#      10 print('Normalized distance between the two sounds:', dist)
#
# TypeError: dtw() got an unexpected keyword argument 'dist'

# %%
img = librosa.display.waveshow(y = y, sr = sr, axis="time")
