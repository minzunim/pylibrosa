# %%
text = 'input/pronunciation_01.mp3'
file = text.split('/')[1]
print(file)
# Out:
# pronunciation_01.mp3

# %%
import os
import librosa
import numpy as np
import soundfile as sf

from pydub import AudioSegment
from pydub.silence import split_on_silence
import os
import subprocess
import speech_recognition as sr

import time

# 원래 파일
origin_folder = "input"
origin_file = "Pronunciation_01.mp3"
final_folder = "final_output"

# 무음 0.5초 추가
silence = AudioSegment.silent(duration=500)

def save_file(origin_file_path):

    # 파일 불러오기
    sound = AudioSegment.from_file(os.path.join(os.getcwd(), origin_file_path))
    sound = sound.set_frame_rate(44100).set_channels(1).set_sample_width(2)

    # 무음 간격으로 끊기
    audio_chunks = split_on_silence(sound,
        min_silence_len=1000, # 최소 무음 길이 (밀리초 단위)
        silence_thresh=-35, # 무음으로 간주되는 dBFS 값
        keep_silence=500 # 분리된 오디오 조각들 간의 추가적인 무음 길이 (밀리초 단위)
    )
    
    for i, chunk in enumerate(audio_chunks):
        if len(chunk) > 15000:
            chunk = chunk[:15000]
        if i < 3:
            pass

        # 강의 안내 방송 이후 시작
        if i >= 3:        

            # chunk 담을 폴더
            chunk_folder = "chunk_output"
            
            # wav로 변환된 chunk (speech to text 모듈은 wav만 지원)
            output_file = os.path.join(chunk_folder, f'chunk_{i}.wav')
            chunk.export(output_file, format='wav')
            print(f'wav: {i}')
            
            if i >= 3 and i % 2 == 0:
                try:
                    file1 = AudioSegment.from_wav(f'{chunk_folder}/chunk_{i - 1}.wav')
                    file2 = AudioSegment.from_wav(f'{chunk_folder}/chunk_{i}.wav')
        
                    title = speech_to_text(f'{chunk_folder}/chunk_{i - 1}.wav')

                    # 중간 무음 추가
                    merge_file = file1 + silence + file2

                    # 현재까지 최종 저장된 파일 개수 확인
                    file_list = os.listdir(final_folder)
                    file_count = len(file_list)

                    # 다시 mp3 로 변환해서 저장
                    merge_file.export(f'{final_folder}/{origin_file_path.split('/')[1]}_{file_count + 1}_{title}.mp3', format="mp3")
                except Exception as e:
                    print(f"Error merging files: {e}")
        # if i >= 5:
        #     break

def speech_to_text(audio_file):
    recognizer = sr.Recognizer()

    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)

    try:
        text = recognizer.recognize_google(audio_data, language='en')
        return text
    except sr.UnknownValueError:
        print("음성을 인식할 수 없습니다.")
    except sr.RequestError:
        print("Google Web API에 접근할 수 없습니다.")
    
    return None

def mp3_to_wav(src_file, dest_file):
    sound = AudioSegment.from_mp3(src_file)
    sound.export(dest_file, format="wav")
    pass

def wav_to_mp3(src_file, dest_file):  
    sound = AudioSegment.from_wav(src_file)  
    sound.export(dest_file, format="mp3")  
    pass

if __name__ == '__main__':
    start = time.time()
    #save_file(f"{origin_folder}/{origin_file}")
    print(f"총 소요시간: {time.time() - start: .4f} sec")
    print("완료")
    pass
# Out:
# wav: 3
# wav: 4
# file_count 0
# merged: 4
# wav: 5
# wav: 6
# file_count 1
# merged: 6
# wav: 7
# wav: 8
# file_count 2
# merged: 8
# wav: 9
# wav: 10
# file_count 3
# merged: 10
# wav: 11
# wav: 12
# file_count 4
# merged: 12
# wav: 13
# wav: 14
# file_count 5
# merged: 14
# wav: 15
# wav: 16
# file_count 6
# merged: 16
# wav: 17
# wav: 18
# file_count 7
# merged: 18
# wav: 19
# wav: 20
# file_count 8
# merged: 20
# wav: 21
# wav: 22
# file_count 9
# merged: 22
# wav: 23
# wav: 24
# file_count 10
# merged: 24
# wav: 25
# wav: 26
# file_count 11
# merged: 26
# wav: 27
# wav: 28
# file_count 12
# merged: 28
# wav: 29
# wav: 30
# file_count 13
# merged: 30
# wav: 31
# wav: 32
# file_count 14
# merged: 32
# wav: 33
# wav: 34
# file_count 15
# merged: 34
# wav: 35
# wav: 36
# file_count 16
# merged: 36
# wav: 37
# wav: 38
# file_count 17
# merged: 38
# wav: 39
# wav: 40
# file_count 18
# merged: 40
# wav: 41
# wav: 42
# file_count 19
# merged: 42
# wav: 43
# wav: 44
# file_count 20
# merged: 44
# wav: 45
# wav: 46
# file_count 21
# merged: 46
# wav: 47
# wav: 48
# file_count 22
# merged: 48
# wav: 49
# wav: 50
# file_count 23
# merged: 50
# wav: 51
# wav: 52
# file_count 24
# merged: 52
# wav: 53
# wav: 54
# file_count 25
# merged: 54
# wav: 55
# wav: 56
# file_count 26
# merged: 56
# wav: 57
# wav: 58
# file_count 27
# merged: 58
# wav: 59
# wav: 60
# file_count 28
# merged: 60
# wav: 61
# wav: 62
# file_count 29
# merged: 62
# wav: 63
# wav: 64
# file_count 30
# merged: 64
# wav: 65
# wav: 66
# file_count 31
# merged: 66
# wav: 67
# wav: 68
# file_count 32
# merged: 68
# wav: 69
# wav: 70
# file_count 33
# merged: 70
# wav: 71
# wav: 72
# file_count 34
# merged: 72
# wav: 73
# wav: 74
# file_count 35
# merged: 74
# wav: 75
# wav: 76
# file_count 36
# merged: 76
# wav: 77
# wav: 78
# file_count 37
# merged: 78
# wav: 79
# wav: 80
# file_count 38
# merged: 80
# wav: 81
# wav: 82
# file_count 39
# merged: 82
# wav: 83
# wav: 84
# file_count 40
# merged: 84
# wav: 85
# wav: 86
# file_count 41
# merged: 86
# wav: 87
# wav: 88
# file_count 42
# merged: 88
# wav: 89
# wav: 90
# file_count 43
# merged: 90
# wav: 91
# wav: 92
# file_count 44
# merged: 92
# wav: 93
# wav: 94
# file_count 45
# merged: 94
# wav: 95
# wav: 96
# file_count 46
# merged: 96
# wav: 97
# wav: 98
# file_count 47
# merged: 98
# wav: 99
# wav: 100
# file_count 48
# merged: 100
# wav: 101
# wav: 102
# file_count 49
# merged: 102
# wav: 103
# wav: 104
# file_count 50
# merged: 104
# wav: 105
# wav: 106
# file_count 51
# merged: 106
# wav: 107
# wav: 108
# file_count 52
# merged: 108
# wav: 109
# wav: 110
# file_count 53
# merged: 110
# wav: 111
# wav: 112
# file_count 54
# merged: 112
# wav: 113
# wav: 114
# file_count 55
# merged: 114
# wav: 115
# wav: 116
# file_count 56
# merged: 116
# wav: 117
# wav: 118
# file_count 57
# merged: 118
# wav: 119
# wav: 120
# file_count 58
# merged: 120
# wav: 121
# wav: 122
# file_count 59
# merged: 122
# wav: 123
# wav: 124
# file_count 60
# merged: 124
# wav: 125
# wav: 126
# file_count 61
# merged: 126
# wav: 127
# wav: 128
# file_count 62
# merged: 128
# wav: 129
# wav: 130
# file_count 63
# merged: 130
# wav: 131
# wav: 132
# file_count 64
# merged: 132
# wav: 133
# wav: 134
# file_count 65
# merged: 134
# wav: 135
# wav: 136
# file_count 66
# merged: 136
# wav: 137
# wav: 138
# file_count 67
# merged: 138
# wav: 139
# wav: 140
# file_count 68
# merged: 140
# wav: 141
# wav: 142
# file_count 69
# merged: 142
# wav: 143
# wav: 144
# file_count 70
# merged: 144
# wav: 145
# wav: 146
# file_count 71
# merged: 146
# wav: 147
# wav: 148
# file_count 72
# merged: 148
# wav: 149
# wav: 150
# file_count 73
# merged: 150
# wav: 151
# wav: 152
# file_count 74
# merged: 152
# wav: 153
# wav: 154
# file_count 75
# merged: 154
# wav: 155
# wav: 156
# file_count 76
# merged: 156
# wav: 157
# wav: 158
# file_count 77
# merged: 158
# wav: 159
# wav: 160
# file_count 78
# merged: 160
# wav: 161
# wav: 162
# file_count 79
# merged: 162
# wav: 163
# wav: 164
# file_count 80
# merged: 164
# wav: 165
# wav: 166
# file_count 81
# merged: 166
# wav: 167
# wav: 168
# file_count 82
# merged: 168
# wav: 169
# wav: 170
# file_count 83
# merged: 170
# wav: 171
# wav: 172
# file_count 84
# merged: 172
# 총 소요시간:  121.1651 sec
# 완료

# %%
import os

folder_path = "path/to/folder"
file_list = os.listdir(folder_path)
file_count = len(file_list)
prin(file
# Out:
# 83

# %%
# chuck 폴더 내 파일 삭제
import os

filePath = 'chunk_output'

for file in os.scandir(filePath):
    os.remove(file.path)

# %%
# final_output 폴더 내 파일 삭제
import os

filePath = 'final_output'

for file in os.scandir(filePath):
    os.remove(file.path)

# %%
import os

os.mkdir('input/hi')

# %%
AudioSegment.ffmpeg = os.getcwd()+"\\ffmpeg\\bin\\ffmpeg.exe"
print(AudioSegment.ffmpeg)

my_file = Path("Pronunciation_01.mp3")
print(my_file)
# Out:
# C:\Users\황민주\dev\pylibrosa\ffmpeg\bin\ffmpeg.exe
# Pronunciation_01.mp3
